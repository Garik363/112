# %%
import random
import pandas as pd
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
print(lst)
print()
data = pd.DataFrame({'whoAmI':lst})
data.loc[data['whoAmI'] == 'robot', 'robot_group'] = '1'
data.loc[data['whoAmI'] != 'robot', 'robot_group'] = '0'
data.loc[data['whoAmI'] == 'human', 'human_group'] = '1'
data.loc[data['whoAmI'] != 'human', 'human_group'] = '0'

data.head(n=20)
# Out:
# ['human', 'robot', 'robot', 'human', 'robot', 'human', 'robot', 'human', 'human', 'robot', 'human', 'robot', 'robot', 'human', 'robot', 'human', 'robot', 'human', 'robot', 'human']
#    whoAmI robot_group human_group
# 0   human           0           1
# 1   robot           1           0
# 2   robot           1           0
# 3   human           0           1
# 4   robot           1           0
# 5   human           0           1
# 6   robot           1           0
# 7   human           0           1
# 8   human           0           1
# 9   robot           1           0
# 10  human           0           1
# 11  robot           1           0
# 12  robot           1           0
# 13  human           0           1
# 14  robot           1           0
# 15  human           0           1
# 16  robot           1           0
# 17  human           0           1
# 18  robot           1           0
# 19  human           0           1
